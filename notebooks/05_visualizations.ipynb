# %% [markdown]
# # Visualizations for Publication and Presentation
#
# This notebook generates all publication-ready figures:
# 1. Covariate balance plot (Love plot)
# 2. CATE by Pell percentage
# 3. CATE by URM percentage
# 4. CATE by MSI type
# 5. Bang-for-buck scatter plot
# 6. SHAP feature importance
# 7. SHAP dependence plot
# 8. Methods comparison forest plot
# 9. Subgroup effects plot
#
# **Expected Runtime:** 10-15 minutes
#
# **Outputs:**
# - `/outputs/figures/*.png` (9 figures at 300 dpi)

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings('ignore')

# Set visualization style
sns.set_style('whitegrid')
sns.set_palette('colorblind')
plt.rcParams['figure.dpi'] = 300
plt.rcParams['font.size'] = 12

print("Visualization libraries imported successfully!")
