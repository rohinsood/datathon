# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook provides descriptive statistics and initial visualizations:
# 1. Descriptive statistics by treatment group
# 2. Correlation analysis
# 3. Outcome distributions
# 4. Outlier detection
# 5. Pre-matching balance checks
#
# **Expected Runtime:** 5-10 minutes
#
# **Outputs:**
# - `/outputs/tables/descriptive_stats.csv`

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# # Exploratory Data Analysis - Load analysis-ready data
#
# **Testing Directions:** Verify data loads correctly with all engineered features.

# %%
# Load analysis-ready data
df = pd.read_csv('/Users/abhiramb/datathon/outputs/data/merged_clean.csv')

print(f"Dataset shape: {df.shape}")
print(f"\nNumber of rows: {df.shape[0]:,}")
print(f"Number of columns: {df.shape[1]}")
print(f"\nColumn summary:")
print(f"  - Total columns: {len(df.columns)}")
print(f"  - Numeric columns: {len(df.select_dtypes(include=[np.number]).columns)}")
print(f"  - Categorical columns: {len(df.select_dtypes(include=['object', 'category']).columns)}")
print(f"\nFirst 5 rows:")
df.head()
# Out:
# Dataset shape: (1825, 270)
#
# Number of rows: 1,825
# Number of columns: 270
#
# Column summary:
#   - Total columns: 270
#   - Numeric columns: 243
#   - Categorical columns: 27
#
# First 5 rows:
#    unit_id      Institution Name_affordability         City  \
# 0   369516                    Bryan University  Springfield
# 1   164492                  Anna Maria College       Paxton
# 2   164465                     Amherst College      Amherst
# 3   164447      American International College  Springfield
# 4   164368  Hult International Business School    Cambridge
#
#   State Abbreviation                              Sector Name  Sector  \
# 0                 MO      Private for-profit, 4-year or above       3
# 1                 MA  Private not-for-profit, 4-year or above       2
# 2                 MA  Private not-for-profit, 4-year or above       2
# 3                 MA  Private not-for-profit, 4-year or above       2
# ...
