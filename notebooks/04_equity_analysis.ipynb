# %% [markdown]
# # Equity Analysis: Heterogeneous Treatment Effects
#
# This notebook analyzes differential effects across equity dimensions:
# 1. Pell-eligible (high vs low) institutions
# 2. High-URM institutions
# 3. Minority-Serving Institutions (HBCUs, HSIs, TCUs)
# 4. Causal forests for continuous CATE
# 5. Intersectional analysis
# 6. Race-specific graduation rate effects
#
# **Expected Runtime:** 15-25 minutes
#
# **Outputs:**
# - `/outputs/tables/heterogeneous_effects.csv`

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

print("Equity analysis libraries imported successfully!")
